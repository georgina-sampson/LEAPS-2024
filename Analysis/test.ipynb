# %%
import constants, Plotting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

folder = '/data2/gsampsonolalde/LEAPS-2024/Analysis/{}'
physical = {constants.SHOCK: ['Time', 'Density', 'gasTemp', 'av', 'zeta', 'radfield', constants.SHOCKVEL],
            constants.HOTCORE: ['Time', 'Density', 'gasTemp', 'av', 'zeta', 'radfield']}
species=['#CH3OH', 'CH3OH', '#SIO', 'SIO']

# %%
singleAxis = True
print('singleAxis',singleAxis)
# Out:
# singleAxis True

# %%
tipo = constants.HOTCORE

# %%
nameBase= folder.format('CorrelationScatterPlots/')+tipo.replace(' ','').upper()+'_'

df= pd.read_csv(folder.format(tipo)+'.csv', index_col=0)
df = df.loc[:,physical[tipo]+species+['runName']]
for prop in physical[tipo]+species:
    with np.errstate(divide='ignore'): df[f'{prop}_log']=np.log10(df[prop])

yaxis= [f'{prop}_log' for prop in species]
if singleAxis: xaxis=yaxis
else: xaxis= [f'{prop}_log' for prop in physical[tipo]]

# %%
figName=nameBase+f"{'species_' if singleAxis else ''}CorrGrid_log_log.png"
corr, fig = Plotting.corrGrid(df, xaxis, yaxis, tipo, 0)
# fig.savefig(figName, dpi=300, bbox_inches='tight')

# %%
xaxis, yaxis = Plotting.getCorrValues(corr, singleAxis)

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}focusedCorrGrid_log_log.png"
    Plotting.corrGrid(df, xaxis, yaxis, tipo, 0.5)[1]

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}scatterGrid_log_log.png"
    Plotting.scatterGrid(df, xaxis, yaxis, tipo, True, True)

# %%
tipo = constants.SHOCK

# %%
nameBase= folder.format('CorrelationScatterPlots/')+tipo.replace(' ','').upper()+'_'

df= pd.read_csv(folder.format(tipo)+'.csv', index_col=0)
df = df.loc[:,physical[tipo]+species+['runName']]
for prop in physical[tipo]+species:
    with np.errstate(divide='ignore'): df[f'{prop}_log']=np.log10(df[prop])

yaxis= [f'{prop}_log' for prop in species]
if singleAxis: xaxis=yaxis
else: xaxis= [f'{prop}_log' for prop in physical[tipo]]

# %%
figName=nameBase+f"{'species_' if singleAxis else ''}CorrGrid_log_log.png"
corr, fig = Plotting.corrGrid(df, xaxis, yaxis, tipo, 0)
# fig.savefig(figName, dpi=300, bbox_inches='tight')

# %%
xaxis, yaxis = Plotting.getCorrValues(corr, singleAxis)

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}focusedCorrGrid_log_log.png"
    Plotting.corrGrid(df, xaxis, yaxis, tipo, 0.5)[1]

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}scatterGrid_log_log.png"
    Plotting.scatterGrid(df, xaxis, yaxis, tipo, True, True)
# Out:
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:50: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logyscale: axs[i][j].set_yscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:50: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logyscale: axs[i][j].set_yscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:50: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logyscale: axs[i][j].set_yscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:50: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logyscale: axs[i][j].set_yscale('log')

# %%
singleAxis = False
print('singleAxis',singleAxis)
# Out:
# singleAxis False

# %%
tipo = constants.HOTCORE

# %%
nameBase= folder.format('CorrelationScatterPlots/')+tipo.replace(' ','').upper()+'_'

df= pd.read_csv(folder.format(tipo)+'.csv', index_col=0)
df = df.loc[:,physical[tipo]+species+['runName']]
for prop in physical[tipo]+species:
    with np.errstate(divide='ignore'): df[f'{prop}_log']=np.log10(df[prop])

yaxis= [f'{prop}_log' for prop in species]
if singleAxis: xaxis=yaxis
else: xaxis= [f'{prop}_log' for prop in physical[tipo]]

# %%
figName=nameBase+f"{'species_' if singleAxis else ''}CorrGrid_log_log.png"
corr, fig = Plotting.corrGrid(df, xaxis, yaxis, tipo, 0)
# fig.savefig(figName, dpi=300, bbox_inches='tight')

# %%
xaxis, yaxis = Plotting.getCorrValues(corr, singleAxis)

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}focusedCorrGrid_log_log.png"
    Plotting.corrGrid(df, xaxis, yaxis, tipo, 0.5)[1]

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}scatterGrid_log_log.png"
    Plotting.scatterGrid(df, xaxis, yaxis, tipo, True, True)
# Out:
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')
# /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:49: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   if logxscale: axs[i][j].set_xscale('log')

# %%
tipo = constants.SHOCK

# %%
nameBase= folder.format('CorrelationScatterPlots/')+tipo.replace(' ','').upper()+'_'

df= pd.read_csv(folder.format(tipo)+'.csv', index_col=0)
df = df.loc[:,physical[tipo]+species+['runName']]
for prop in physical[tipo]+species:
    with np.errstate(divide='ignore'): df[f'{prop}_log']=np.log10(df[prop])

yaxis= [f'{prop}_log' for prop in species]
if singleAxis: xaxis=yaxis
else: xaxis= [f'{prop}_log' for prop in physical[tipo]]

# %%
figName=nameBase+f"{'species_' if singleAxis else ''}CorrGrid_log_log.png"
corr, fig = Plotting.corrGrid(df, xaxis, yaxis, tipo, 0)
# fig.savefig(figName, dpi=300, bbox_inches='tight')

# %%
xaxis, yaxis = Plotting.getCorrValues(corr, singleAxis)

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}focusedCorrGrid_log_log.png"
    Plotting.corrGrid(df, xaxis, yaxis, tipo, 0.5)[1]

# %%
if len(xaxis)>1 or len(yaxis)>0:
    figName=nameBase+f"{'species_' if singleAxis else ''}scatterGrid_log_log.png"
    Plotting.scatterGrid(df, xaxis, yaxis, tipo, True, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 if len(xaxis)>1 or len(yaxis)>0:
#       2     figName=nameBase+f"{'species_' if singleAxis else ''}scatterGrid_log_log.png"
# ----> 3     Plotting.scatterGrid(df, xaxis, yaxis, tipo, True, True)
#
# File /data2/gsampsonolalde/LEAPS-2024/Analysis/Plotting.py:46, in scatterGrid(df, xaxis, yaxis, title, logxscale, logyscale)
#      44 for i, spec in enumerate(xaxis):
#      45     for j, phys in enumerate(yaxis):
# ---> 46         sns.scatterplot(df,x=spec,y=phys,ax=axs[i][j],
#      47                         hue='runName', palette='Spectral', s=10,
#      48                         legend= 'auto' if i==0 and j==int(np.ceil(len(yaxis)/2)-1) else None)
#      49         if logxscale: axs[i][j].set_xscale('log')
#      50         if logyscale: axs[i][j].set_yscale('log')
#
# TypeError: 'Axes' object is not subscriptable
